# %%
import yaml

yaml_file_path="text.yaml"

with open(yaml_file_path,'r') as yaml_file:
    data=yaml.safe_load(yaml_file)

print(data)
print(type(data))
# Out:
# {'name': 'adarsh', 'email': 'adarshkumar23724@gmail.com'}
# <class 'dict'>

# %%
data["name"]
# Out:
# 'adarsh'

# %%
data["email"]
# Out:
# 'adarshkumar23724@gmail.com'

# %%
#config box
from box import ConfigBox

d=ConfigBox(data)

# %%
d
# Out:
# ConfigBox({'name': 'adarsh', 'email': 'adarshkumar23724@gmail.com'})

# %%
d.name
# Out:
# 'adarsh'

# %%
d.email
# Out:
# 'adarshkumar23724@gmail.com'

# %%
#ensure_annotations

def get_product(x:int,y:int):
    return x*y

# %%
get_product(x=2,y=4)
# Out:
# 8

# %%
get_product(x=2,y="4")
# Out:
# '44'
